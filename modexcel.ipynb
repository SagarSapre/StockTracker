# %%
import pandas as pd
import streamlit as st
#this files import xl file into panda and saves it in modified form

# %%
path ='E:\\sagar\\2 sagar ORDER\\ORDER\\Prgramming\\python\\projects\\stocktracker\\mutual fund data\\sbi\\2021-January-SBI EQUITY HYBRID FUND PORTFOLIO.xlsx'

# %%
A=pd.read_excel(path)

# %%
cols = ['A','B','C','D','E','F','G','H','I','J']
A.columns = cols
print(A.columns)
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'], dtype='object')

# %%
A
# Out:
#       A   B                                                  C
# 0   NaN NaN                                    SBI MUTUAL FUND  \
# 1   NaN NaN                                      SCHEME NAME :
# 2   NaN NaN                        PORTFOLIO STATEMENT AS ON :
# 3   NaN NaN                                                NaN
# 4   NaN NaN                    Name of the Instrument / Issuer
# ..   ..  ..                                                ...
# 167 NaN NaN  1. Non Convertible Debentures and  Bonds are c...
# 168 NaN NaN  2. ^Industry classification as recommended by ...
# 169 NaN NaN  3. Security is in default beyond its maturity ...
# 170 NaN NaN                                   Name of Security
# 171 NaN NaN      RHFL 08.70% (Series I Cat I & II) 03-Jan-2020
#
#                           D
# 0                       024  \
# 1    SBI Equity Hybrid Fund
# 2       2021-01-31 00:00:00
# 3                       NaN
# 4                      ISIN
# ..                      ...
# 167                     NaN
# 168                     NaN
# 169                     NaN
# 170                    ISIN
# 171            INE217K07AB6
#
#                                                      E
# 0                                                  NaN  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                   Rating / Industry^
# ..                                                 ...
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170  Value of the security considered under net rec...
# 171                                                  0
#
#                                                      F
# 0                                                  NaN  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                             Quantity
# ..                                                 ...
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170  Value of the security considered under net rec...
# 171                                                  0
#
#                                                      G         H      I
# 0                                                  NaN       NaN    NaN  \
# 1                                                  NaN       NaN    NaN
# 2                                                  NaN       NaN    NaN
# 3                                                  NaN       NaN    NaN
# 4                         Market value\n(Rs. in Lakhs)  % to AUM  YTM %
# ..                                                 ...       ...    ...
# 167                                                NaN       NaN    NaN
# 168                                                NaN       NaN    NaN
# 169                                                NaN       NaN    NaN
# 170  Total amount (Including Principal and Interest...       NaN    NaN
# 171                                              10870       NaN    NaN
#
#                    J
# 0      Back to Index
# 1                NaN
# 2                NaN
# 3                NaN
# 4    Notes & Symbols
# ..               ...
# 167              NaN
# 168              NaN
# 169              NaN
# 170              NaN
# 171              NaN
#
# [172 rows x 10 columns]

# %%
#B=A.drop([0])

# %%
amc_name=A.iloc[0][2]
amc_name
# Out:
# 'SBI MUTUAL FUND'

# %%
as_on=A.iloc[2][3]
as_on
# Out:
# datetime.datetime(2021, 1, 31, 0, 0)

# %%
scheme_name=A.iloc[1][3]
scheme_name
# Out:
# 'SBI Equity Hybrid Fund'

# %%
b=A.axes
b
#172*9
# Out:
# [RangeIndex(start=0, stop=172, step=1),
#  Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'], dtype='object')]

# %%
b=A.drop([0,1,2,3],inplace=True)
b

# %%
b=A.drop(['A','B'] ,axis=1,inplace=True)
A
# Out:
#                                                      C             D
# 4                      Name of the Instrument / Issuer          ISIN  \
# 5                                                  NaN           NaN
# 6                              EQUITY & EQUITY RELATED           NaN
# 7        a) Listed/awaiting listing on Stock Exchanges           NaN
# 8                                       HDFC Bank Ltd.  INE040A01034
# ..                                                 ...           ...
# 167  1. Non Convertible Debentures and  Bonds are c...           NaN
# 168  2. ^Industry classification as recommended by ...           NaN
# 169  3. Security is in default beyond its maturity ...           NaN
# 170                                   Name of Security          ISIN
# 171      RHFL 08.70% (Series I Cat I & II) 03-Jan-2020  INE217K07AB6
#
#                                                      E
# 4                                   Rating / Industry^  \
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                Banks
# ..                                                 ...
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170  Value of the security considered under net rec...
# 171                                                  0
#
#                                                      F
# 4                                             Quantity  \
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                             14000000
# ..                                                 ...
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170  Value of the security considered under net rec...
# 171                                                  0
#
#                                                      G         H      I
# 4                         Market value\n(Rs. in Lakhs)  % to AUM  YTM %  \
# 5                                                  NaN       NaN    NaN
# 6                                                  NaN       NaN    NaN
# 7                                                  NaN       NaN    NaN
# 8                                               194670      5.62    NaN
# ..                                                 ...       ...    ...
# 167                                                NaN       NaN    NaN
# 168                                                NaN       NaN    NaN
# 169                                                NaN       NaN    NaN
# 170  Total amount (Including Principal and Interest...       NaN    NaN
# 171                                              10870       NaN    NaN
#
#                    J
# 4    Notes & Symbols
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# ..               ...
# 167              NaN
# 168              NaN
# 169              NaN
# 170              NaN
# 171              NaN
#
# [168 rows x 8 columns]

# %%
'''

EQUITY & EQUITY RELATED
a) Listed/awaiting listing on Stock Exchanges
Total
b) Unlisted
c) Foreign Securities and /or overseas ETF
DEBT INSTRUMENTS
b) Privately Placed/Unlisted
c) Securitised Debt Instruments
d) Central Government Securities
e) State Government Securities
MONEY MARKET INSTRUMENTS
a) Commercial Paper
b) Certificate of Deposits
c) Treasury Bills
d) Bills Re- Discounting
OTHERS
a) Mutual Fund Units / Exchange Traded Funds
b) Gold
c) Short Term Deposits
d) Term Deposits Placed as Margins
e) TREPS / Reverse Repo Investments
Other Current Assets / (Liabilities)
DERIVATIVES
Stock Futures
Index Futures
Derivatives Total
3. Security is in default beyond its maturity date :

'''
# Out:
# '\n\nEQUITY & EQUITY RELATED\na) Listed/awaiting listing on Stock Exchanges\nTotal\nb) Unlisted\nc) Foreign Securities and /or overseas ETF\nDEBT INSTRUMENTS\nb) Privately Placed/Unlisted\nc) Securitised Debt Instruments\nd) Central Government Securities\ne) State Government Securities\nMONEY MARKET INSTRUMENTS\na) Commercial Paper\nb) Certificate of Deposits\nc) Treasury Bills\nd) Bills Re- Discounting\nOTHERS\na) Mutual Fund Units / Exchange Traded Funds\nb) Gold\nc) Short Term Deposits\nd) Term Deposits Placed as Margins\ne) TREPS / Reverse Repo Investments\nOther Current Assets / (Liabilities)\nDERIVATIVES\nStock Futures\nIndex Futures\nDerivatives Total\n3. Security is in default beyond its maturity date :\n\n'

# %%
s = pd.Series(list('abc'))
