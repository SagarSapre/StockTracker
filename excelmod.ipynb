# %%
import pandas as pd

# %%
path='E:\\sagar\\2 sagar ORDER\\ORDER\\Prgramming\\python\\projects\\stocktracker\\mutual fund data\\sbi'

# %%
a=pd.read_excel('E:\\sagar\\2 sagar ORDER\\ORDER\\Prgramming\\python\\projects\\stocktracker\\mutual fund data\\sbi\\2021-January-SBI EQUITY HYBRID FUND PORTFOLIO.xlsx', index_col=0)

# %%
a
# Out:
#      Unnamed: 1                                         Unnamed: 2
# NaN         NaN                                    SBI MUTUAL FUND  \
# NaN         NaN                                      SCHEME NAME :
# NaN         NaN                        PORTFOLIO STATEMENT AS ON :
# NaN         NaN                                                NaN
# NaN         NaN                    Name of the Instrument / Issuer
# ..          ...                                                ...
# NaN         NaN  1. Non Convertible Debentures and  Bonds are c...
# NaN         NaN  2. ^Industry classification as recommended by ...
# NaN         NaN  3. Security is in default beyond its maturity ...
# NaN         NaN                                   Name of Security
# NaN         NaN      RHFL 08.70% (Series I Cat I & II) 03-Jan-2020
#
#                  Unnamed: 3
# NaN                     024  \
# NaN  SBI Equity Hybrid Fund
# NaN     2021-01-31 00:00:00
# NaN                     NaN
# ...
